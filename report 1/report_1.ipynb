# %% [markdown]
# # MIT Drone Design Report #1
# ## 1. General Recap
#
# - ✅ [Have assembled drone and ran maiden flight]
# - ✅ [Found NDAA compliant tof for potential use in LiDAR]
# - ✅ [Created schematic for sensor, a PCB can be quickly made if desired]
# - ✅ Built Guide for Pure Ubuntu users (not just Windows)

# %% [markdown]
# ## 2. Drone Hardware Assembled
#
#
# Two potential sensors were found, both built by Broadcom that could potentially meet the requirements for Jerry's ToF sensor. I reached out and they noted the ArkElectronics breakout boards as examples of NDAA uses
#
# - **[AFBR-S50LV85D](https://www.broadcom.com/products/optical-sensors/time-of-flight-3d-sensors/afbr-s50lv85d):** 30m range standard, up to 100m in dual-frequency mode (capped at 100 Hz frame rate at long range; up to 3 kHz in short-range single-frequency mode). 12.4° × 6.2° FoV, 32 pixels, SPI. ~$60/unit single-qty on DigiKey.
# - **[AFBR-S50LX85D](https://www.broadcom.com/products/optical-sensors/time-of-flight-3d-sensors/afbr-s50lx85d):** 50mm to 50m range, same 100 Hz cap in dual-frequency long-range mode, up to 3 kHz short-range. Optimized for drone and industrial long-range sensing. ~$87–91/unit single-qty on DigiKey.
#
# <figure style="text-align: center; margin: 0;">
#   <img src="./figures/tof_schematic.png" alt="Basic schematic for AFBR-S50LV85D ToF sensor" style="width: 70%; height: auto;">
#   <figcaption><em>Basic schematic for ToF sensor</em></figcaption>
# </figure>
#
#
#
# - **[Shortcoming 1]:** Further progress depends on simulation testing and verification of Jerry's mini-lidar
# - **[Shortcoming 2]:** The sensors are close to meeting all specifications required, but price is a concern
#
#
# **Links:**
# - CAD: [link label](url)
# - PCB: [link label](url)
#
#
# **Status:** Work is on hold until we do more work on the software stack to verify that lidar scanning with the hardware we can build will be sufficient

# %% [markdown]
# ## 3. NDAA Tof Sensor
#
#
# Two potential sensors were found, both built by Broadcom that could potentially meet the requirements for Jerry's ToF sensor. I reached out and they noted the ArkElectronics breakout boards as examples of NDAA uses
#
# - **[AFBR-S50LV85D](https://www.broadcom.com/products/optical-sensors/time-of-flight-3d-sensors/afbr-s50lv85d):** 30m range standard, up to 100m in dual-frequency mode (capped at 100 Hz frame rate at long range; up to 3 kHz in short-range single-frequency mode). 12.4° × 6.2° FoV, 32 pixels, SPI. ~$60/unit single-qty on DigiKey.
# - **[AFBR-S50LX85D](https://www.broadcom.com/products/optical-sensors/time-of-flight-3d-sensors/afbr-s50lx85d):** 50mm to 50m range, same 100 Hz cap in dual-frequency long-range mode, up to 3 kHz short-range. Optimized for drone and industrial long-range sensing. ~$87–91/unit single-qty on DigiKey.
#
# <figure style="text-align: center; margin: 0;">
#   <img src="./figures/tof_schematic.png" alt="Basic schematic for AFBR-S50LV85D ToF sensor" style="width: 70%; height: auto;">
#   <figcaption><em>Basic schematic for ToF sensor</em></figcaption>
# </figure>
#
#
#
# - **[Shortcoming 1]:** Further progress depends on simulation testing and verification of Jerry's mini-lidar
# - **[Shortcoming 2]:** The sensors are close to meeting all specifications required, but price is a concern
#
#
# **Links:**
# - CAD: [link label](url)
# - PCB: [link label](url)
#
#
# **Status:** Work is on hold until we do more work on the software stack to verify that lidar scanning with the hardware we can build will be sufficient

# %% [markdown]
# ## 4. Summary & Future Work
#
# ### Summary
#
# - Finished hardware set up and have notes written down for Jerry about the set up guide
# - Found NDAA ToF SEnsor for mini-lidar and have schematic that can easily be spun into a pcb if desired
# - [One-line recap of major accomplishment 3]
#
# ### Future Work
#
# - [ ] **[Task]:** [short description]
# - [ ] **[Task]:** [short description]
# - [ ] **[Task]:** [short description]
