# %% [markdown]
# # [Project Name], Follow-Up #[N]
#
# ## 1. Recap from [Last Period]
#
# - ✅ [Completed item with brief result]
# - ✅ [Completed item with brief result]
# - ✅ [Completed item with brief result]
# - ✅ [Outstanding item or next target]

# %% [markdown]
# ## 2. [First Work Item]
#
# ### V1: [Subsection Title]
#
# [Short paragraph describing what was built, the key technique, and the headline result. Keep it conversational, first-person, no em-dashes.]
#
# <div style="display: flex; justify-content: center; align-items: flex-start; gap: 20px; flex-wrap: wrap;">
#   <figure style="width: 40%; text-align: center; margin: 0;">
#     <img src="figures/placeholder1.jpg" alt="[alt text]" style="width: 70%; height: auto;">
#     <figcaption><em>[Caption for figure 1]</em></figcaption>
#   </figure>
#   <figure style="width: 40%; text-align: center; margin: 0;">
#     <img src="figures/placeholder2.jpg" alt="[alt text]" style="width: 70%; height: auto;">
#     <figcaption><em>[Caption for figure 2]</em></figcaption>
#   </figure>
# </div>
#
# [Optional transition sentence introducing shortcomings or next step:]
#
# - **[Shortcoming 1]:** [one-line explanation]
# - **[Shortcoming 2]:** [one-line explanation]
#
# ### V2: [Subsection Title]
#
# [Short paragraph describing the next iteration and what it addresses.]
#
# <div style="display: flex; justify-content: center; align-items: flex-start; gap: 20px; flex-wrap: wrap;">
#   <figure style="width: 40%; text-align: center; margin: 0;">
#     <img src="figures/placeholder3.png" alt="[alt text]" style="width: 80%; height: auto;">
#     <figcaption><em>[Caption]</em></figcaption>
#   </figure>
#   <figure style="width: 40%; text-align: center; margin: 0;">
#     <img src="figures/placeholder4.png" alt="[alt text]" style="width: 80%; height: auto;">
#     <figcaption><em>[Caption]</em></figcaption>
#   </figure>
# </div>
#
# **Links:**
# - CAD: [link label](url)
# - PCB: [link label](url)
#
# **Features:**
#
# - ✅ **[Feature]:** [one-line detail]
# - ✅ **[Feature]:** [one-line detail]
# - ✅ **[Feature]:** [one-line detail]
# - ✅ **[Feature]:** [one-line detail]
#
# **Status:** [where the work is now and what is next].

# %% [markdown]
# ## 3. [Second Work Item]
#
# ### Why [This Topic]
#
# [1-2 sentence motivation for the section.]
#
# 1. **[Reason 1]:** [short justification]
# 2. **[Reason 2]:** [short justification]
#
# ### System Architecture
#
# [Optional lead-in sentence.]
#
# **[Diagram 1 Label]:**
#
# ```mermaid
# %%{init: {'themeVariables': {'fontSize': '14px'}, 'flowchart': {'nodeSpacing': 20, 'rankSpacing': 30, 'padding': 8}}}%%
# graph LR
#     subgraph GroupA[Group A]
#         A1[Node A1]
#         A2[Node A2]
#     end
#
#     subgraph GroupB[Group B]
#         B1[Node B1]
#         B2[Node B2]
#     end
#
#     A1 -->|label| B1
#     B1 --> B2
#     A2 <-->|label| B2
# ```
#
# **[Diagram 2 Label]:**
#
# ```mermaid
# %%{init: {'themeVariables': {'fontSize': '14px'}, 'flowchart': {'nodeSpacing': 20, 'rankSpacing': 30, 'padding': 8}}}%%
# graph LR
#     A[Node A] --> B[Node B]
#     B --> C[Node C]
# ```
#
# ### What Was Built
#
# [Paragraph describing what was implemented this cycle.]
#
# - **Repo 1:** [link](url)
# - **Repo 2:** [link](url)
# - **Repo 3:** [link](url)
#
# > ⚠️ [Callout: a caveat, warning, or instruction to the reader.]

# %% [markdown]
# ## 4. Summary & Future Work
#
# ### Summary
#
# - [One-line recap of major accomplishment 1]
# - [One-line recap of major accomplishment 2]
# - [One-line recap of major accomplishment 3]
#
# ### Future Work
#
# - [ ] **[Task]:** [short description]
# - [ ] **[Task]:** [short description]
# - [ ] **[Task]:** [short description]
#
# <div style="display: flex; justify-content: center; align-items: flex-start; gap: 20px; flex-wrap: wrap;">
#   <figure style="width: 45%; text-align: center; margin: 0;">
#     <img src="figures/placeholder5.png" alt="[alt text]" style="width: 80%; height: auto;">
#     <figcaption><em>[Caption]</em></figcaption>
#   </figure>
#   <figure style="width: 35%; text-align: center; margin: 0;">
#     <img src="figures/placeholder6.jpg" alt="[alt text]" style="width: 80%; height: auto;">
#     <figcaption><em>[Caption]</em></figcaption>
#   </figure>
# </div>
